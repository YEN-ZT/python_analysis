# %% [markdown]
# https://www.perplexity.ai/search/94f7fc8c-0595-416f-b080-1e318bd7404d

# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1   -1.734682
#    2    1.057246
#    3    0.778811
# b  1   -0.618673
#    2   -0.220927
# c  3   -0.246412
#    1    0.754886
# d  2   -0.566561
#    3   -1.271173
# dtype: float64

# %%
data['a']
# Out:
# 1   -1.734682
# 2    1.057246
# 3    0.778811
# dtype: float64

# %%
data['a'][2]
# Out:
# np.float64(1.0572462005828225)

# %%
#Series->堆疊資料>(long data)
#2維資料->非堆疊資料>(width data)
data.unstack()
# Out:
#           1         2         3
# a -1.734682  1.057246  0.778811
# b -0.618673 -0.220927       NaN
# c  0.754886       NaN -0.246412
# d       NaN -0.566561 -1.271173

# %%
data.index.names = ['key1','key2']
data.groupby(level='key1').sum()
# Out:
# key1
# a    0.101375
# b   -0.839600
# c    0.508473
# d   -1.837734
# dtype: float64

# %% [markdown]
# ## 使用unstack()時,(組合)索引不可以重複

# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(10),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd','a'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3,1]])
#索引(a,1)重複了,無法做unstack
data.unstack()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 8
#       4 data = pd.Series(np.random.randn(10),
#       5                 index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd','a'],
#       6                        [1, 2, 3, 1, 2, 3, 1, 2, 3,1]])
#       7 #索引(a,1)重複了,無法做unstack
# ----> 8 data.unstack()
#
# File c:\Users\s4292\miniconda3\envs\myenv\lib\site-packages\pandas\core\series.py:4615, in Series.unstack(self, level, fill_value, sort)
#    4570 """
#    4571 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4572
#    (...)
#    4611 b    2    4
#    4612 """
#    4613 from pandas.core.reshape.reshape import unstack
# -> 4615 return unstack(self, level, fill_value, sort)
#
# File c:\Users\s4292\miniconda3\envs\myenv\lib\site-packages\pandas\core\reshape\reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File c:\Users\s4292\miniconda3\envs\myenv\lib\site-packages\pandas\core\reshape\reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File c:\Users\s4292\miniconda3\envs\myenv\lib\site-packages\pandas\core\reshape\reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(10),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd','a'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3,1]])
#索引(a,1)重複了,無法做unstack
#必需先groupby完後,才可以unstack
data.index.names = ['key1','key2']
data1 = data.groupby(level=['key1','key2']).sum()
data1.unstack()
# Out:
# key2         1         2         3
# key1
# a    -0.104874 -0.109259  0.714811
# b     1.084247 -0.851515       NaN
# c    -0.064082       NaN -0.917434
# d          NaN -0.765819 -2.157518

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                    index=[['a','a','b','b'],[1, 2, 1, 2]],
                    columns=[['台北','台北','台中'],['Green','Red','Green']])
frame.index.names = ['key1','key2']
frame.columns.names = ['縣市','顏色']
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
series1 = frame.stack(level=['縣市','顏色'],future_stack=True)
series1.unstack(level=['key1', '縣市'])
# Out:
# key1          a          b
# 縣市           台北   台中    台北    台中
# key2 顏色
# 1    Green  0.0  2.0   6.0   8.0
#      Red    1.0  NaN   7.0   NaN
# 2    Green  3.0  5.0   9.0  11.0
#      Red    4.0  NaN  10.0   NaN

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                    index=[['a','a','b','b'],[1, 2, 1, 2]],
                    columns=[['台北','台北','台中'],['Green','Red','Green']])
frame.index.names = ['key1','key2']
frame.columns.names = ['縣市','顏色']
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
frame.T.groupby(level='顏色').sum()
# Out:
# key1   a      b
# key2   1  2   1   2
# 顏色
# Green  2  8  14  20
# Red    1  4   7  10
