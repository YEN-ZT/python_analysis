# %% [markdown]
# https://www.perplexity.ai/search/83b26786-5e8e-4cbe-ac68-acf4626be7c8

# %%
import os
folder_name = '每日各站進出站人數'
folder_abspath = os.path.abspath(folder_name)
allitems:list[str] = os.listdir(folder_abspath)

# for file_name in allitems:
#     if len(file_name) > 12:
#         print(file_name)

#綜合串列運算語法(comprehension)

filenames = [file_name for file_name in allitems if len(file_name) > 12]
for file_name in filenames:
    filename_absPath = os.path.join(folder_abspath, file_name)
    print(filename_absPath)
# Out:
# c:\Users\s4292\OneDrive\文件\github\python_analysis\lesson18\每日各站進出站人數\每日各站進出站人數20190423-20191231.csv
# c:\Users\s4292\OneDrive\文件\github\python_analysis\lesson18\每日各站進出站人數\每日各站進出站人數2020.csv
# c:\Users\s4292\OneDrive\文件\github\python_analysis\lesson18\每日各站進出站人數\每日各站進出站人數2021.csv
# c:\Users\s4292\OneDrive\文件\github\python_analysis\lesson18\每日各站進出站人數\每日各站進出站人數2022.csv

# %%
import pandas as pd
import os
csv_absPath = os.path.join(folder_abspath,filenames[0])
df = pd.read_csv(csv_absPath)
site_df = pd.read_csv(os.path.abspath('台鐵車站資訊.csv'))
print(df.columns)
print(site_df.columns)
df1 = pd.merge(df,site_df,left_on='staCode',right_on='stationCode',how='left')
# Out:
# Index(['trnOpDate', 'staCode', 'gateInComingCnt', 'gateOutGoingCnt'], dtype='object')
# Index(['stationCode', 'stationName', 'name', 'stationAddrTw', 'stationTel',
#        'gps', 'haveBike'],
#       dtype='object')

# %%
df2 = df1.reindex(columns=['trnOpDate','staCode','gateInComingCnt','gateOutGoingCnt','name','stationAddrTw','gps','haveBike'])

# %%
df3 = df2.rename(columns={'trnOpDate':'日期',
                    'staCode':'代碼',
                    'gateInComingCnt':'進站人數',
                    'gateOutGoingCnt':'出站人數',
                    'name':'站名',
                    'stationAddrTw':'地址',
                    'gps':'gps',
                    'haveBike':'youBike'
                    })

# %%
df4 = df3.dropna()
df4['日期'] = pd.to_datetime(df4['日期'].astype(str))
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60129 entries, 0 to 60128
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   日期       60129 non-null  datetime64[ns]
#  1   代碼       60129 non-null  int64
#  2   進站人數     60129 non-null  int64
#  3   出站人數     60129 non-null  int64
#  4   站名       60129 non-null  object
#  5   地址       60129 non-null  object
#  6   gps      60129 non-null  object
#  7   youBike  60129 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 3.7+ MB

# %%
df4
# Out:
#               日期    代碼  進站人數  出站人數   站名  \
# 0     2019-04-23   900  8442  7743   基隆
# 1     2019-04-23   910  1394  1348   三坑
# 2     2019-04-23   920  2770  2423   八堵
# 3     2019-04-23   930  6113  6335   七堵
# 4     2019-04-23   940  2680  2726   百福
# ...          ...   ...   ...   ...  ...
# 60124 2019-12-31  7360  5779  5782   瑞芳
# 60125 2019-12-31  7361   146   142  海科館
# 60126 2019-12-31  7362   116   134  八斗子
# 60127 2019-12-31  7380   654   585  四腳亭
# 60128 2019-12-31  7390   448   396   暖暖
#
#                                                   地址                 gps  \
# 0                                        基隆市仁愛區港西街5號  25.13411 121.73997
# 1                                 基隆市仁愛區德厚里龍安街 206 號  25.12305 121.74202
# 2                                 基隆市暖暖區八南里八堵路 142 號  25.10843 121.72898
# 3                                   基隆市七堵區長興里東新街 2 號  25.09294 121.71415
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號  25.07795 121.69379
# ...                                              ...                 ...
# 60124                            新北市瑞芳區龍潭里明燈路三段 82 號  25.10861 121.80596
# 60125                                      基隆市中正區長潭里  25.13754 121.79997
# 60126  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)  25.13545 121.80261
# 60127                              新北市瑞芳區吉慶里中央路 65 號  25.10283 121.76192
# 60128                              基隆市暖暖區暖暖里暖暖街 51 號  25.10224 121.74048
#
#       youBike
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           N
# ...       ...
# 60124       Y
# 60125       N
# 60126       N
# 60127       N
# 60128       N
#
# [60129 rows x 8 columns]
